# %% [markdown]
# ## Unit 4 lesson 1.4
#
# ### Write Your Own Story

# %% [markdown]
# 1\. My ideal job would be at a large company based in Silicon valley. I would like to excercise my expertice in science and communication to create and distribute compelling models in business developement, product design, and predictive analytics. My strengths in machine learning and data manipulation could be used to roll out customer-facing analytics and strategic initiatives.

# %% [markdown]
# 2\. In a non-techical way; my ideal job is using data to further the goals and successes of the company I work for. Furthering business and finicial missions while creating a clear vision of the past and future climate of initiatives.

# %% [markdown]
# 3\. With a specialization in creating concise and compelling reports, I can using my strengths in machine learning and data visualization to provide clear insites into bussiness strategy. My ideal pos
