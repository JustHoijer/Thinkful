# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from matplotlib.mlab import PCA as mlabPCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df1 = pd.read_csv("../Datafile/liander_electricity_01012009.csv")
df1['year'] = '2009'
df2 = pd.read_csv("../Datafile/liander_electricity_01012010.csv")
df2['year'] = '2010'
df3 = pd.read_csv("../Datafile/liander_electricity_01012011.csv")
df3['year'] = '2011'
df4 = pd.read_csv("../Datafile/liander_electricity_01012012.csv")
df4['year'] = '2012'
df5 = pd.read_csv("../Datafile/liander_electricity_01012013.csv")
df5['year'] = '2013'
df6 = pd.read_csv("../Datafile/liander_electricity_01012014.csv")
df6['year'] = '2014'
df7 = pd.read_csv("../Datafile/liander_electricity_01012015.csv")
df7['year'] = '2015'
df8 = pd.read_csv("../Datafile/liander_electricity_01012016.csv")
df8['year'] = '2016'
df9 = pd.read_csv("../Datafile/liander_electricity_01012017.csv")
df9['year'] = '2017'
df10 = pd.read_csv("../Datafile/liander_electricity_01012018.csv")
df10['year'] = '2018'

df = pd.concat([df1,df2,df3,df4, df5, df6, df7, df8, df9, df10])
df = df.loc[(df['city']=='AMSTERDAM')]

# %%
df = df.drop(['net_manager', 'purchase_area', 'street', 'zipcode_from', 'zipcode_to', 'city'], axis=1)
df.head()

# %%
#df.to_csv('../Amesterdamdata.csv', encoding='utf-8', index=False)
