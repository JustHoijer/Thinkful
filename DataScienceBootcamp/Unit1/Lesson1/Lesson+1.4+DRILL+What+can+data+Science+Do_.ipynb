# %% [markdown]
# ### Prompt
# For each question, describe how you would make it testable and translate it from a general question into something statistically rigorous. Write your answers down in a shareable document and submit the link below.

# %% [markdown]
# #### Question 1\.
# You work at an e-commerce company that sells three goods: widgets, doodads, and fizzbangs. The head of advertising asks you which they should feature in their new advertising campaign. You have data on individual visitors' sessions (activity on a website, pageviews, and purchases), as well as whether or not those users converted from an advertisement for that session. You also have the cost and price information for the goods.

# %% [markdown]
# #### Response 1
# Based on the provided information (manly reporting to head of advertising), I would immediately compare the three good's advertisement success. After determining which product benefits most from advertisement, the next step would be to take a deep dive into all the available analytics.
#
# To gain statisticaly compelling results, I'd use the site analytics on a per-good basis. Starting with the most advertisment-convert prone, I'd put together reports providing insight into advertisment's impact on user's site activity and ultimately their procliving to purchase. Things like 1\. how/when advertisements were used in way that led to beneficial site activity 2\.which of the products may or may not be selling more without advertisements and 3\.Which product makes the most money(and recieves the most attention) regardless of avertisement.
#
# In the end, the combination of advertisement impact and earning power would influence my sugesstion for which product to focus on in the advertising campaign.

# %% [markdown]
# #### Question 2
# You work at a web design company that offers to build websites for clients. Signups have slowed, and you are tasked with finding out why. The onboarding funnel has three steps: email and password signup, plan choice, and payment. On a user level you have information on what steps they have completed as well as timestamps for all of those events for the past 3 years. You also have information on marketing spend on a weekly level.

# %% [markdown]
# #### Response 2
# I'd like to point out that the first step in the on boarding funnel is to signup(which is what is being prompted as the main area of concern). The data scientist in me cann't help but point that out.
#
# Understanding that the growth of new clients is slowing; my first goal with the provided data would be to identify which, if any, of the boarding funnel steps is acting like a bottleneck. This insight can paint a picture of how plan choices and costs/payment may be affecting our aquisition of users. I'd be interested in things like time spent on each section and attempt to associate delays/underiable actions with some front end language or naunce.
#
# After hopefully identifying some solvable issues with the onboarding process, I'd move on to the marketing data. I'd guess that this data will provide the majority of insight into user acquisition. Of course, confirming that would be one of the first things to look at with this data (confirming 1:1 relationship between weekly-marketing expenditure and user signups). Quite significantly, if the current drop in user acquisition is due to a lack of marketing than that would take center stage in my report. Beyond that, I would take a look at how varying levels of spending have impacted user signups. I'd use statistics to determine the significance/correlation with dollars spent and users added. These results would be summarized to provide guidance into the different thresholds of marketing and when/how much spending would be most beneficial.

# %% [markdown]
# #### Question 3
# You work at a hotel website and currently the website ranks search results by price. For simplicity's sake, let's say it's a website for one city with 100 hotels. You are tasked with proposing a better ranking system. You have session information, price information for the hotels, and whether each hotel is currently available.

# %% [markdown]
# #### Response 3
#
# I'd take a look at user's time-spend, session activity, and page-views for each hotel and it's associated price and availability. Specifically, a attempt would be made to connect user's activity with another potential ranking system. I'd create hypotetical ranking systems for hotel data such as their rating, previous bookings through our website, or distance from signifant locations. I would then compare user activity (mainly page views) to these hypothetical ranking systems. A final result would be constructed from a combination of user-data and a easily catagorized ranking system.

# %% [markdown]
# #### Question 4
# You work at a social network, and the management is worried about churn (users stopping using the product). You are tasked with finding out if their churn is atypical. You have three years of data for users with an entry for every time they've logged in, including the timestamp and length of session.

# %% [markdown]
# #### Response 4
#
# To determine the significance of this potential churn, the past slumps in product use and current user environment will be ecspecially useful. Since the data only provides the timestamp and length of session, I'd first take a look at the correlation been number of users and length of session for the entire data set. In doing this, I would determine any general trends such as time dependent activity and user-activity decline/ increase.
#
# If there are similarities between the past activity slumps/rises and the current state of the product, then that would suggest the churn is a false alarm. However, if there can be no relationship draw AND the slump is significantly worse than in the past than I'd suggest the churn is atypical.
