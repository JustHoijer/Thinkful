# %% [markdown]
# ### Unit 1 Lesson 4.3: Am I Biased?
#
# For each of the following scenarios, call out the potential biases in the proposed experiment. Do your best to try to discover not only the bias, but the initial design. There is plenty of room for interpretation here, so make sure to state what assumptions you're making.
#
# - You're testing advertising emails for a bathing suit company and you test one version of the email in February and the other in May.
# - You open a clinic to treat anxiety and find that the people who visit show a higher rate of anxiety than the general population.
# - You launch a new ad billboard based campaign and see an increase in website visits in the first week.
# - You launch a loyalty program but see no change in visits in the first week.

# %% [markdown]
# 1\. In this senerio, there the testing method is flaud. The difference between February and May regarding bathing suit business is a big red flag. The results of the two emails cannot be accurately compared because the timing has caused context factors and bias.

# %% [markdown]
# 2\. Initially, these results seem legitement. However, the clearly the people who visit the clinic have higher levels of anxiety than the average person. The sample is not a random split when comparing the general population to a select group of axiety prone individuals. Not only do the samples paint an inherently biased picture, it could be argued that people at the clinic would be more willing or comfortable with rating their anxiety at higher levels.

# %% [markdown]
# 3\. The bias in this example include outside factors and disputable results. The rise in website visits could be the result of outside factors or coincidence. More context would be needed to understand the imapct of the billboards; things like visability, location, and impact. Without making a connection between sample size and website visits, its hard to creating any meaningful connection.

# %% [markdown]
# 4\. Again, the issue here is between the connection to sample and outcomes. Without important metrics like the number of program signups, the frequency of member visits, and other factors that may effect member visits; it's impossible to make informed conclusions about the validity of the loyalty program.
